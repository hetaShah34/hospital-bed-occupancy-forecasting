# %% [markdown]
# # Hospital Bed Occupancy Forecasting
#
# This notebook is a cleaned project workflow that uses the modular scripts in `src/`.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

DATA_PATH = PROJECT_ROOT / 'data' / 'raw' / 'weekly_hospital_respiratory_data.csv'
PROCESSED_PATH = PROJECT_ROOT / 'data' / 'processed' / 'hospital_bed_occupancy_clean.csv'
FIG_DIR = PROJECT_ROOT / 'outputs' / 'figures'
TABLE_DIR = PROJECT_ROOT / 'outputs' / 'tables'

FIG_DIR.mkdir(parents=True, exist_ok=True)
TABLE_DIR.mkdir(parents=True, exist_ok=True)
PROJECT_ROOT

# %% [markdown]
# ## 2. Load and preprocess data

# %%
from data_preprocessing import DataPreprocessor

processor = DataPreprocessor(reporting_threshold=0.80)

# Uncomment after placing the raw dataset in data/raw/
# raw_df = processor.load_data(DATA_PATH)
# clean_df, summary = processor.preprocess(raw_df)
# processor.save_processed_data(clean_df, PROCESSED_PATH)
# print(summary)

# %% [markdown]
# ## 3. Load processed data

# %%
import pandas as pd

# Uncomment after preprocessing
# df = pd.read_csv(PROCESSED_PATH, parse_dates=['Week Ending Date'])
# df.head()

# %% [markdown]
# ## 4. Exploratory data analysis

# %%
from eda import (
    plot_national_occupancy,
    plot_region_rankings,
    plot_correlation_heatmap,
    plot_top_region_series,
    decompose_series,
    stationarity_report,
)

# plot_national_occupancy(df, FIG_DIR / 'national_occupancy.png')
# plot_region_rankings(df, FIG_DIR / 'region_rankings.png')
# corr = plot_correlation_heatmap(df, FIG_DIR / 'correlation_heatmap.png')
# plot_top_region_series(df, out_path=FIG_DIR / 'top_regions.png')
# decompose_series(df, out_dir=FIG_DIR)
# stationarity_report(df, regions=['TX', 'CA', 'FL'])

# %% [markdown]
# ## 5. State-level modeling

# %%
from modeling_tx import run_tx_modeling
from modeling_ca import run_ca_modeling
from modeling_fl import run_fl_modeling

# tx_metrics, tx_forecast = run_tx_modeling(df, plot=True)
# ca_metrics, ca_forecast = run_ca_modeling(df, plot=True)
# fl_metrics, fl_forecast = run_fl_modeling(df, plot=True)

# tx_metrics, ca_metrics, fl_metrics

# %% [markdown]
# ## 6. Save metrics tables

# %%
from evaluation import save_metrics_table

# save_metrics_table(tx_metrics, TABLE_DIR / 'tx_model_metrics.csv')
# save_metrics_table(ca_metrics, TABLE_DIR / 'ca_model_metrics.csv')
# save_metrics_table(fl_metrics, TABLE_DIR / 'fl_model_metrics.csv')

# %% [markdown]
# ## Notes
#
# - Put the raw dataset in `data/raw/`.
# - Run preprocessing first.
# - Then run EDA and modeling cells.
# - The state scripts are intentionally separated so your GitHub repo is easier to read than a single long notebook.
